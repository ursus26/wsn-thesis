# %% [markdown]
# #### Name: Bart de Haan
# #### ID: 11044616
#
# This file loads in the energy consumption of individual nodes and plots the energy consumption.

# %%
import numpy as np
import matplotlib.pyplot as plt
import os
import csv

# %%
path = "./energy/"
file_names = os.listdir(path)
files = [path + file for file in file_names]

# %%
nodes = []

# Loop over all the files.
for f in files:
    # Read the time and energy value of a file.
    with open(f, newline='') as csvfile:
        battery_level = csv.reader(csvfile, quotechar='|')
        battery_level = [x for x in battery_level]
        battery_level = battery_level[1:]
        
        entry = [[float(t), float(e)] for t, e in battery_level]
        entry = np.array(entry)

        nodes.append(entry)

# %%
plt.figure(figsize=(11, 6))

for n in nodes:
    plt.plot(n[:, 0], n[:, 1], alpha=0.75)

    
plt.xlabel('Time (Seconds)', fontsize=14)
plt.ylabel('Energy (Joule)', fontsize=14)
plt.margins(x=0)
plt.xlim(xmax=40)
plt.ylim(ymin=0)
plt.grid(True)
plt.show()
